# %% [markdown]
# # **RAINFALL ANALYSIS(Weather Dataset)**

# %% [markdown]
# # **Downloading the Dataset**

# %%
# !pip install opendatasets --upgrade --quiet

# %%
dataset_url = 'https://www.kaggle.com/rstogi896/rainfall-in-india'

# %%
import opendatasets as od
od.download(dataset_url)

# %%
data_dir = './rainfall-in-india'

# %%
import os
os.listdir(data_dir)
# Out:
# ['Sub_Division_IMD_2017.csv']

# %%
project_name = "analysis-of-rainfall-in-india"

# %% [markdown]
# # **Data Preparation and Cleaning**

# %%
import pandas as pd
rainfall_df=pd.read_csv(r'rainfall-in-india/Sub_Division_IMD_2017.csv')

# %%
rainfall_df
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     Andaman & Nicobar Islands  1901  49.2   87.1   29.2    2.3  528.8
# 1     Andaman & Nicobar Islands  1902   0.0  159.8   12.2    0.0  446.1
# 2     Andaman & Nicobar Islands  1903  12.7  144.0    0.0    1.0  235.1
# 3     Andaman & Nicobar Islands  1904   9.4   14.7    0.0  202.4  304.5
# 4     Andaman & Nicobar Islands  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4183                Lakshadweep  2013  26.2   34.4   37.5    5.3   88.3
# 4184                Lakshadweep  2014  53.2   16.1    4.4   14.9   57.4
# 4185                Lakshadweep  2015   2.2    0.5    3.7   87.1  133.1
# 4186                Lakshadweep  2016  59.6   12.1    3.2    2.6   77.4
# 4187                Lakshadweep  2017  21.3    0.9  100.2    1.8  145.7
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM  \
# ...

# %%
rainfall_df.shape
# Out:
# (4188, 19)

# %%
rainfall_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4188 entries, 0 to 4187
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4188 non-null   object
#  1   YEAR         4188 non-null   int64
#  2   JAN          4184 non-null   float64
#  3   FEB          4185 non-null   float64
#  4   MAR          4182 non-null   float64
#  5   APR          4184 non-null   float64
#  6   MAY          4185 non-null   float64
#  7   JUN          4183 non-null   float64
#  8   JUL          4181 non-null   float64
#  9   AUG          4184 non-null   float64
#  10  SEP          4182 non-null   float64
#  11  OCT          4181 non-null   float64
#  12  NOV          4177 non-null   float64
#  13  DEC          4178 non-null   float64
#  14  ANNUAL       4162 non-null   float64
#  15  JF           4182 non-null   float64
#  16  MAM          4179 non-null   float64
#  17  JJAS         4178 non-null   float64
# ...

# %%
rainfall_df.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4188.000000  4184.000000  4185.000000  4182.000000  4184.000000
# mean   1959.220630    18.938337    21.599427    27.412912    43.071845
# std      33.717097    33.793128    35.731734    46.927963    68.150985
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.500000     1.000000     3.000000
# 50%    1959.000000     5.950000     6.500000     7.900000    15.450000
# 75%    1988.000000    22.000000    26.600000    31.375000    49.650000
# max    2017.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4185.000000  4183.000000  4181.000000  4184.000000  4182.000000
# mean     85.660860   230.117475   347.020043   289.742185   197.316332
# std     122.695137   234.292087   268.850702   188.426071   135.547646
# ...

# %%
rainfall_df.groupby('SUBDIVISION')['ANNUAL'].mean()
# Out:
# SUBDIVISION
# Andaman & Nicobar Islands             2926.373585
# Arunachal Pradesh                     3403.959140
# Assam & Meghalaya                     2579.133333
# Bihar                                 1196.563248
# Chhattisgarh                          1369.136752
# Coastal Andhra Pradesh                1050.304274
# Coastal Karnataka                     3397.637931
# East Madhya Pradesh                   1203.035043
# East Rajasthan                         656.501709
# East Uttar Pradesh                     975.864957
# Gangetic West Bengal                  1490.612821
# Gujarat Region                         917.827350
# Haryana Delhi & Chandigarh             528.439316
# Himachal Pradesh                      1256.781197
# Jammu & Kashmir                       1138.842241
# Jharkhand                             1307.689744
# Kerala                                2914.247009
# Konkan & Goa                          2987.531624
# ...

# %% [markdown]
# # **Exploratory Analysis and Visualization**

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
kerala_df=rainfall_df[rainfall_df.SUBDIVISION=="Kerala"]
plt.plot(kerala_df.YEAR,kerala_df.ANNUAL,c="#6b011f")

# %%
bihar_df=rainfall_df[rainfall_df.SUBDIVISION=="Bihar"]
chhattisgarh_df=rainfall_df[rainfall_df.SUBDIVISION=="Chhattisgarh"]
plt.plot(bihar_df.YEAR,bihar_df.ANNUAL)
plt.plot(chhattisgarh_df.YEAR,chhattisgarh_df.ANNUAL)
plt.title("Rainfall in Bihar and Chhattisgarh")
plt.legend(['Bihar','Chhattisgarh'])
plt.xlabel('Year')
plt.ylabel('Rainfall in mm')
# Out:
# Text(0, 0.5, 'Rainfall in mm')

# %%
ktaka1_df=rainfall_df[rainfall_df.SUBDIVISION=="Coastal Karnataka"]
ktaka2_df=rainfall_df[rainfall_df.SUBDIVISION=="North Interior Karnataka"]
plt.scatter(ktaka1_df.YEAR,ktaka1_df.ANNUAL,c="hotpink")
plt.scatter(ktaka2_df.YEAR,ktaka2_df.ANNUAL,c="#aa2ee6")
plt.title("Rainfall in Karntaka")
plt.legend(['Coastal','Interior'])
plt.xlabel('Year')
plt.ylabel('Rainfall in mm')
# Out:
# Text(0, 0.5, 'Rainfall in mm')

# %%
plt.plot(kerala_df.YEAR,kerala_df.JAN,c="#161d6f",ls='-.')

# %%
plt.scatter(kerala_df.YEAR,kerala_df.JAN,c="Red",ls='--')

# %%
fig,axes=plt.subplots(4,3,figsize=(15,10))
plt.tight_layout(pad=2)

axes[0,0].plot(kerala_df.YEAR,kerala_df.JAN,c="#ba135d")
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Rainfall in mm')
axes[0,0].set_title('Rainfall in january')

axes[0,1].plot(kerala_df.YEAR,kerala_df.FEB,c="#0a81ab")
axes[0,1].set_xlabel('Year')
axes[0,1].set_ylabel('Rainfall in mm')
axes[0,1].set_title('Rainfall in february')

axes[0,2].plot(kerala_df.YEAR,kerala_df.MAR,c="#962d2d")
axes[0,2].set_xlabel('Year')
axes[0,2].set_ylabel('Rainfall in mm')
axes[0,2].set_title('Rainfall in march')

axes[1,0].plot(kerala_df.YEAR,kerala_df.APR,c="#233e8b")
axes[1,0].set_xlabel('Year')
axes[1,0].set_ylabel('Rainfall in mm')
axes[1,0].set_title('Rainfall in april')

axes[1,1].plot(kerala_df.YEAR,kerala_df.MAY,c="#1eae98")
axes[1,1].set_xlabel('Year')
axes[1,1].set_ylabel('Rainfall in mm')
axes[1,1].set_title('Rainfall in may')

axes[1,2].plot(kerala_df.YEAR,kerala_df.JUN,c="#890596")
axes[1,2].set_xlabel('Year')
axes[1,2].set_ylabel('Rainfall in mm')
axes[1,2].set_title('Rainfall in june')

axes[2,0].plot(kerala_df.YEAR,kerala_df.JUL,c="#f55c47")
axes[2,0].set_xlabel('Year')
axes[2,0].set_ylabel('Rainfall in mm')
axes[2,0].set_title('Rainfall in jul')

axes[2,1].plot(kerala_df.YEAR,kerala_df.AUG,c="#c449c2")
axes[2,1].set_xlabel('Year')
axes[2,1].set_ylabel('Rainfall in mm')
axes[2,1].set_title('Rainfall in august')

axes[2,2].plot(kerala_df.YEAR,kerala_df.SEP,c="#29bb89")
axes[2,2].set_xlabel('Year')
axes[2,2].set_ylabel('Rainfall in mm')
axes[2,2].set_title('Rainfall in september')

axes[3,0].plot(kerala_df.YEAR,kerala_df.OCT,c="#ce1f6a")
axes[3,0].set_xlabel('Year')
axes[3,0].set_ylabel('Rainfall in mm')
axes[3,0].set_title('Rainfall in october')

axes[3,1].plot(kerala_df.YEAR,kerala_df.NOV,c="#ffc93c")
axes[3,1].set_xlabel('Year')
axes[3,1].set_ylabel('Rainfall in mm')
axes[3,1].set_title('Rainfall in november')

axes[3,2].plot(kerala_df.YEAR,kerala_df.DEC,c="#f39189")
axes[3,2].set_xlabel('Year')
axes[3,2].set_ylabel('Rainfall in mm')
axes[3,2].set_title('Rainfall in december')
# Out:
# Text(0.5, 1.0, 'Rainfall in december')

# %%
plt.plot(kerala_df.YEAR,kerala_df.JAN,c="#161d6f",ls='--')

# %%
subset_df=rainfall_df.groupby('YEAR').agg(mean_ann=('ANNUAL','mean'))
subset_df=subset_df.reset_index()
set_df=subset_df.tail(15)
plt.figure(figsize=(15,8))
sns.barplot(x=set_df.YEAR,y='mean_ann',data=set_df)
# Out:
# <Axes: xlabel='YEAR', ylabel='mean_ann'>

# %%
plt.figure(figsize=(16,10), dpi=100)
plt.plot(kerala_df.YEAR,kerala_df.JAN, color='tab:red')
plt.gca().set(title="Kerala Rainfall", xlabel='Year')
plt.show()

# %% [markdown]
# # **Asking and Answering Questions**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q1: TODO - In which year did india it received highest rainfall and also which state that year received highest rainfall?

# %%
subset_df=rainfall_df.groupby('YEAR').agg(mean_ann=('ANNUAL','mean'))
subset_df=subset_df.reset_index()
subset_df
# Out:
#      YEAR     mean_ann
# 0    1901  1284.214286
# 1    1902  1337.302857
# 2    1903  1399.908824
# 3    1904  1236.771429
# 4    1905  1186.177143
# ..    ...          ...
# 112  2013  1475.172222
# 113  2014  1244.336111
# 114  2015  1280.583333
# 115  2016  1273.694444
# 116  2017  1368.005556
#
# [117 rows x 2 columns]

# %%
subset_df.max()
# Out:
# YEAR        2017.0
# mean_ann    1717.1
# dtype: float64

# %% [markdown]
# Q2: TODO - In which year does kerala receives rainfall less than 2000mm?

# %%
kerala_df=rainfall_df[rainfall_df.SUBDIVISION=="Kerala"]
kerala_df=kerala_df[kerala_df['ANNUAL']<2000]
kerala_df
# Out:
#      SUBDIVISION  YEAR  JAN   FEB   MAR   APR    MAY    JUN    JUL    AUG  \
# 4070      Kerala  2016  3.0  16.4  22.4  33.3  258.4  595.7  441.5  231.0
#
#        SEP    OCT   NOV   DEC  ANNUAL    JF    MAM    JJAS    OND
# 4070  84.1  105.1  57.9  22.0  1870.9  19.3  314.2  1352.3  185.0

# %% [markdown]
# Q3: TODO - Plot a graph on june-sept trend of rainfall

# %%
plt.figure(figsize=(15,8))
plt.title("June-Sept analysis")
plt.xlabel("Year")
plt.ylabel("Rainfall in mm")
plt.scatter(rainfall_df.YEAR,rainfall_df.JJAS)

# %% [markdown]
# Q4: Downloading another dataset and merge it with rainfall dataset

# %%
dataset2_url = 'https://www.kaggle.com/mahendran1/weather-data-in-india-from-1901-to-2017'

# %%
import opendatasets as od
od.download(dataset2_url)

# %%
data_dir = './weather-data-in-india-from-1901-to-2017'

# %%
import os
os.listdir(data_dir)
# Out:
# ['Weather Data in India from 1901 to 2017.csv']

# %%
weather_df=pd.read_csv(r'weather-data-in-india-from-1901-to-2017/Weather Data in India from 1901 to 2017.csv')
weather_df
# Out:
#      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
#        SEP    OCT    NOV    DEC
# ...

# %%
subset_df=rainfall_df.groupby('YEAR').agg(mean_ann=('ANNUAL','mean'))
subset_df=subset_df.reset_index()
combined_df=subset_df.merge(weather_df,on="YEAR")
combined_df
# Out:
#      YEAR     mean_ann  Unnamed: 0    JAN    FEB    MAR    APR    MAY    JUN  \
# 0    1901  1284.214286           0  17.99  19.43  23.49  26.41  28.28  28.60
# 1    1902  1337.302857           1  19.00  20.39  24.10  26.54  28.68  28.44
# 2    1903  1399.908824           2  18.32  19.79  22.46  26.03  27.93  28.41
# 3    1904  1236.771429           3  17.77  19.39  22.95  26.73  27.83  27.85
# 4    1905  1186.177143           4  17.40  17.79  21.78  24.84  28.32  28.69
# ..    ...          ...         ...    ...    ...    ...    ...    ...    ...
# 112  2013  1475.172222         112  18.88  21.07  24.53  26.97  29.06  28.24
# 113  2014  1244.336111         113  18.81  20.35  23.34  26.91  28.45  29.42
# 114  2015  1280.583333         114  19.02  21.23  23.52  26.52  28.82  28.15
# 115  2016  1273.694444         115  20.92  23.58  26.61  29.56  30.41  29.70
# 116  2017  1368.005556         116  20.59  23.08  25.58  29.17  30.47  29.44
#
# ...

# %%
max_index=combined_df['mean_ann'].idxmax()
combined_df.loc[max_index]
# Out:
# YEAR          1961.00
# mean_ann      1717.10
# Unnamed: 0      60.00
# JAN             18.89
# FEB             19.08
# MAR             23.84
# APR             26.42
# MAY             28.07
# JUN             27.80
# JUL             27.08
# AUG             26.89
# SEP             26.45
# OCT             24.23
# NOV             20.98
# DEC             18.30
# Name: 60, dtype: float64

# %%
min_index=combined_df['mean_ann'].idxmin()
combined_df.loc[min_index]
# Out:
# YEAR          1972.000000
# mean_ann      1146.488889
# Unnamed: 0      71.000000
# JAN             18.400000
# FEB             18.730000
# MAR             23.430000
# APR             25.850000
# MAY             28.080000
# JUN             28.700000
# JUL             27.370000
# AUG             26.760000
# SEP             26.260000
# OCT             24.270000
# NOV             21.910000
# DEC             19.460000
# Name: 71, dtype: float64

# %% [markdown]
# Q5: TODO - When does India have summer season?

# %%
mean_df=combined_df[['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']].mean()
mean_df
# Out:
# JAN    18.423248
# FEB    20.137949
# MAR    23.434188
# APR    26.514103
# MAY    28.386410
# JUN    28.300940
# JUL    27.369231
# AUG    26.940085
# SEP    26.342650
# OCT    24.742051
# NOV    21.765726
# DEC    19.173333
# dtype: float64

# %% [markdown]
# Q6: Live Weather

# %%
import requests
from bs4 import BeautifulSoup

city = "Bangalore"

url = 'https://www.google.com/search?q=weather+' + city

html = requests.get(url).content

soup = BeautifulSoup(html, 'html.parser')

temp = soup.find('div', attrs={'class': 'BNeawe iBp4i AP7Wnd'}).text

str = soup.find('div', attrs={'class': 'BNeawe tAd8D AP7Wnd'}).text

data = str.split('\n')
time = data[0]
sky = data[1]

listdiv = soup.findAll('div', attrs={'class': 'BNeawe s3v9rd AP7Wnd'})

strd = listdiv[5].text

pos = strd.find('Wind')
other_data = strd[pos:]

print("   L I V E  W E A T H E R   \n")
print("City            : ", city)
print("Temperature     : ", temp)
print("Time            : ", time)
print("Sky Description : ", sky)
print("\t\t  ",other_data)
# Out:
#    L I V E  W E A T H E R
#
# City            :  Bangalore
# Temperature     :  78°F
# Time            :  Thursday 6:05 PM
# Sky Description :  Mostly cloudy
# 		   Windy and partly cloudy. High 28ºC.
